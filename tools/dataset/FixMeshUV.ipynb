# %%
import torch
import numpy as np

def load_obj(filename_obj, normalization=True, texture_size=4, load_texture=False,
             texture_wrapping='REPEAT', use_bilinear=True, use_cuda = False):
    """
    Load Wavefront .obj file.
    This function only supports vertices (v x x x) and faces (f x x x).
    """

    # read in all lines
    with open(filename_obj) as f:
        lines = f.readlines()

    # load vertices
    vertices = []
    for line in lines:
        if len(line.split()) == 0:
            continue
        if line.split()[0] == 'v':
            vertices.append([float(val) for val in line.split()[1:4]])
    vertices = torch.from_numpy(np.vstack(vertices).astype(np.float32))
    if use_cuda:
        vertices = vertices.cuda()

    # load vertex normal
    vertices_normal = []
    has_vn = False
    for line in lines:
        if len(line.split()) == 0:
            continue
        if line.split()[0] == 'vn':
            vertices_normal.append([float(val) for val in line.split()[1:4]])
    if vertices_normal:
        vertices_normal = torch.from_numpy(np.vstack(vertices_normal).astype(np.float32))
        if use_cuda:
            vertices_normal = vertices_normal.cuda()
        has_vn = True

    # load vertex texture coordinates
    vertices_texcoords = []
    has_vt = False
    for line in lines:
        if len(line.split()) == 0:
            continue
        if line.split()[0] == 'vt':
            vertices_texcoords.append([float(val) for val in line.split()[1:3]])
    if vertices_texcoords:
        vertices_texcoords = torch.from_numpy(np.vstack(vertices_texcoords).astype(np.float32))
        if use_cuda:
            vertices_texcoords = vertices_texcoords.cuda()
        has_vt = True

    # load faces
    faces = []
    faces_vn_idx = []
    faces_vt_idx = []
    face_mtl_idx = []
    face_mtl_names = []
    for line in lines:
        if len(line.split()) == 0:
            continue
            
        if line.split()[0] == 'usemap':
            face_mtl_names.append(line.split()[1])
            face_mtl_idx.append(len(faces))
            #print(line.split()[1])
            
        if line.split()[0] == 'f':
            vs = line.split()[1:]
            nv = len(vs)
            face = [int(vs[i].split('/')[0]) for i in range(nv)]
            faces.append(face)
            if has_vt:
                face_vt_idx = [int(vs[i].split('/')[1]) for i in range(nv)]
                faces_vt_idx.append(face_vt_idx)
            if has_vn:
                face_vn_idx = [int(vs[i].split('/')[-1]) for i in range(nv)]
                faces_vn_idx.append(face_vn_idx)
    faces = torch.from_numpy(np.vstack(faces).astype(np.int32)) - 1
    if len(faces_vn_idx)>0:
        faces_vn_idx = torch.from_numpy(np.vstack(faces_vn_idx).astype(np.int32)) - 1
    if len(faces_vt_idx)>0:
        faces_vt_idx = torch.from_numpy(np.vstack(faces_vt_idx).astype(np.int32)) - 1
    # face_mtl_idx = torch.from_numpy(np.vstack(face_mtl_idx).astype(np.int32))
    if use_cuda:
        faces = faces.cuda()
        faces_vn_idx = faces_vn_idx.cuda()
        faces_vt_idx = faces_vt_idx.cuda()

    # load textures
    textures = None
    if load_texture:
        for line in lines:
            if line.startswith('mtllib'):
                filename_mtl = os.path.join(os.path.dirname(filename_obj), line.split()[1])
                textures = load_textures(filename_obj, filename_mtl, texture_size,
                                         texture_wrapping=texture_wrapping,
                                         use_bilinear=use_bilinear)
        if textures is None:
            raise Exception('Failed to load textures.')

    # normalize into a unit cube centered zero
    #if normalization:
    #    vertices -= vertices.min(0)[0][None, :]
    #    vertices /= torch.abs(vertices).max()
    #    vertices *= 2
    #    vertices -= vertices.max(0)[0][None, :] / 2

    v_attr = {'v' : vertices, 'vn' : vertices_normal, 'vt' : vertices_texcoords}
    # f_mtl_idx: start idx of face for a mtl group
    # f_mtl_names: mtl group names
    f_attr = {'f_v_idx' : faces, 'f_vn_idx' : faces_vn_idx, 'f_vt_idx' : faces_vt_idx}
    # f_attr = {'f_v_idx' : faces, 'f_vn_idx' : faces_vn_idx, 'f_vt_idx' : faces_vt_idx, 'f_mtl_idx': face_mtl_idx, 'f_mtl_names': face_mtl_names}

    if load_texture:
        return v_attr, f_attr, textures 
    else:
        return v_attr, f_attr

# %%
import os
def save_obj(filename, v_attr, f_attr):
    vertices = v_attr['v']
    vertices_normal = v_attr['vn']
    vertices_textures = v_attr['vt']
    faces = f_attr['f_v_idx']
    assert vertices.ndimension() == 2
    assert faces.ndimension() == 2

    #f textures is not None:
    filename_mtl = 'cx_white.mtl'
    filename_texture = 'cx_white.png'
    material_name = 'material_1'
    #texture_image, vertices_textures = create_texture_image(textures)
    #imsave(filename_texture, texture_image)

    faces = faces.detach().cpu().numpy()

    with open(filename, 'w') as f:
        f.write('# %s\n' % os.path.basename(filename))
        f.write('#\n')
        f.write('\n')

        f.write('mtllib %s\n\n' % os.path.basename(filename_mtl))

        for vertex in vertices:
            f.write('v %.8f %.8f %.8f\n' % (vertex[0], vertex[1], vertex[2]))
        f.write('\n')

        for normal in vertices_normal:
            f.write('vn %.8f %.8f %.8f\n' % (normal[0], normal[1], normal[2]))
        f.write('\n')
        
        for vertex in vertices_textures.reshape((-1, 2)):
            f.write('vt %.8f %.8f\n' % (vertex[0], vertex[1]))
        f.write('\n')

        f.write('usemtl %s\n' % material_name)
        for face, faces_vt_idx,faces_vn_idx in zip(f_attr['f_v_idx'], f_attr['f_vt_idx'], f_attr['f_vn_idx']):
            f.write('f %d/%d/%d %d/%d/%d %d/%d/%d\n' % (               \
                 face[0]+ 1, faces_vt_idx[0] + 1, faces_vn_idx[0] + 1, \
                 face[1]+ 1, faces_vt_idx[1] + 1, faces_vn_idx[1] + 1, \
                 face[2]+ 1, faces_vt_idx[2] + 1, faces_vn_idx[2] + 1))
        f.write('\n')

    with open(filename_mtl, 'w') as f:
        f.write('newmtl %s\n' % material_name)
        f.write('map_Kd %s\n' % os.path.basename(filename_texture))

# %%
# mesh lab function
from pathlib import *
def meshlab_resave(modelname, outputname):
    #odelname = Path(modelname)
    # meshlabserver = "D:\\MeshLab\\meshlabserver.exe"
    scriptname = " -s compute_v_normal.mlx"
    # output_params = " -m vc"
    meshlabserver = "meshlabserver"
    
    cmd = meshlabserver + " -i " + str(modelname) + scriptname + " -o " + str(outputname) + " -om vn"
    print(cmd)
    os.system(cmd)

# %%
# # rename image
# path = '/data/NFS/new_disk/chenxin/relightable-nr/data/realdome_cx/rgb0/'
# image_pattern = 'image.cam%02d_%06d.png'
# new_pattern = '%03d.png'
# for iF in range(20,151):
#     for iC in range(1,81):
#         orig_path = path + str(iF) + '/' + image_pattern%(iC,iF)
#         new_path = path + str(iF) + '/' + new_pattern%(iC-1)
#         print(orig_path)
#         print(new_path)
#         os.rename(orig_path, new_path)

# move obj
Path = '/data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/'
# obj_pattern = '/%d/3DDeformed/%d_nonrigidRefinded_test0327_13.ply'
new_obj_pattern = '../mesh/%d.obj'
for iF in range(0,310):
    # obj_path = path + obj_pattern%(iF,iF)
    new_path = path + new_obj_pattern%(iF)
    #meshlab_resave(obj_path, new_path)
    meshlab_resave(new_path, new_path)
# Out:
# meshlabserver -i /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/../mesh
obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/149.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/150.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/151.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/152.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/153.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/154.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/155.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/156.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/157.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/158.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/159.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/160.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/161.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/162.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/163.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/164.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/165.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/166.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/167.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/168.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/169.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/170.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/171.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/172.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/173.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/174.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/175.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/176.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/177.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/178.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/179.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/180.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/181.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/182.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/183.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/184.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/185.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/186.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/187.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/188.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/189.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/190.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/191.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/192.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/193.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/194.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/195.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/196.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/197.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/198.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/199.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/200.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/201.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/202.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/203.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/204.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/205.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/206.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/207.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/208.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/209.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/210.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/211.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/212.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/213.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/214.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/215.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/216.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/217.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/218.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/219.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/220.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/221.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/222.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/223.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/224.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/225.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/226.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/227.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/228.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/229.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/230.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/231.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/232.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/233.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/234.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/235.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/236.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/237.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/238.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/239.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/240.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/241.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/242.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/243.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/244.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/245.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/246.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/247.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/248.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/249.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/250.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/251.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/252.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/253.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/254.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/255.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/256.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/257.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/258.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/259.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/260.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/261.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/262.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/263.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/264.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/265.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/266.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/267.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/268.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/269.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/270.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/271.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/272.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/273.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/274.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/275.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/276.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/277.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/278.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/279.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/280.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/281.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/282.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/283.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/284.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/285.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/286.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/287.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/288.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/289.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/290.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/291.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/292.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/293.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/294.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/295.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/296.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/297.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/298.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/299.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/300.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/301.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/302.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/303.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/304.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/305.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/306.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/307.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/308.obj
# /data/NFS/new_disk/chenxin/relightable-nr/data/mars_cx/mesh/309.obj

# %%
for im in range(160,350):
    filename = '.\..\obj\%03d.obj'%(im)
    filename_save = './../obj_merge/\%03d.obj'%(im)

    #filename = '160.obj'
    
    print('load mesh: ' + filename)
    v_attr, f_attr = load_obj(filename)
    fs_length = f_attr['f_v_idx'].shape[0]

    print('merge vertex coordinate ...')
    for i in range(0,f_attr['f_mtl_idx'].shape[0]):
        mtl_g = [];
        if i+1 < f_attr['f_mtl_idx'].shape[0]:
            mtl_g = range(f_attr['f_mtl_idx'][i],f_attr['f_mtl_idx'][i+1]);
        else:
            mtl_g = range(f_attr['f_mtl_idx'][i],fs_length);

        # merge vt            
        faces = np.reshape(f_attr['f_v_idx'][mtl_g],[-1,1]).tolist() # get face indx    
        if f_attr['f_mtl_names'][i] == 'surfaceShader_cloth':
            v_attr['vt'][faces] = v_attr['vt'][faces] * torch.from_numpy(np.array([0.8, 1]).astype(np.float32))
        if f_attr['f_mtl_names'][i] == 'surfaceShader_head':
            v_attr['vt'][faces] = torch.from_numpy(np.array([0.8, 0.75]).astype(np.float32)) + \
                                  v_attr['vt'][faces] * torch.from_numpy(np.array([0.2, 0.25]).astype(np.float32))
        if f_attr['f_mtl_names'][i] == 'surfaceShader_eye':
            v_attr['vt'][faces] = torch.from_numpy(np.array([0.8, 0.5]).astype(np.float32)) + \
                                  v_attr['vt'][faces] * torch.from_numpy(np.array([0.2, 0.25]).astype(np.float32))
        if f_attr['f_mtl_names'][i] == 'surfaceShader_body':
            v_attr['vt'][faces] = torch.from_numpy(np.array([0.8, 0.25]).astype(np.float32)) + \
                                  v_attr['vt'][faces] * torch.from_numpy(np.array([0.2, 0.25]).astype(np.float32))
        if f_attr['f_mtl_names'][i] == 'surfaceShader_shoes':
            v_attr['vt'][faces] = torch.from_numpy(np.array([0.8, 0]).astype(np.float32)) + \
                                  v_attr['vt'][faces] * torch.from_numpy(np.array([0.2, 0.25]).astype(np.float32))
    save_obj(filename_save, v_attr, f_attr)
