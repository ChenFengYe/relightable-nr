# %%
#!pip install smplx
#!pip install chamferdist

import time
import json as js
import numpy as np
import os
from os.path import join, exists

import torch
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import smplx
from smplx.lbs import *
#import chamferdist
#from chamferdist import ChamferDist
from chamfer_distance import ChamferDistance

from plyfile import PlyData, PlyElement
import pandas as pd
import pickle as pkl
import math

# %%
gpu_id = [0]

if len(gpu_id) > 0 and torch.cuda.is_available():
    os.environ['CUDA_VISIBLE_DEVICES'] = str(gpu_id[0])
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
    
torch.cuda.set_device(1)

# %%
SMPL_joints = [1, 2,  4,  5,  7,  8, 10, 11, 12, 16, 17, 18, 19, 20, 21, 24, 25, 26, 27, 28, 6, 3, 0, 9,]
OPOS_joints = [12, 9, 13, 10, 14, 11, 19, 22,  1,  5,  2,  6,  3,  7,  4,  0, 15, 16, 17, 18, ]

print(len(SMPL_joints))
# Out:
# 24

# %%
def load_ske(path):
    if not exists(path):
        raise ValueError(path)

    skeleton = []
    f = open(path)
    for line in f.readlines():
        numbers = line.split()        # 将数据分隔
        numbers_float = map(float, numbers) #转化为浮点数
        skeleton.append(list(numbers_float)[:3])
    f.close()
    
    skeleton = np.array(skeleton)
    skeleton = torch.from_numpy(skeleton)    
    return skeleton

def customize_load_smplx_params(path):
    with open(path, 'rb') as smplx_file:
        model_data = pkl.load(smplx_file, encoding='latin1')
    for (k,v) in model_data.items(): 
            model_data[k] = torch.from_numpy(v).double().to(device)
    return model_data

def customize_save_smplx_params(model_data, path):
    for (k,v) in model_data.items(): 
            model_data[k] = v.detach().cpu().double().numpy()
    with open(path, 'wb') as f:
           pkl.dump(model_data, f, protocol=2)    

def customize_save_ply(vs, fs, path):
    vs = [(vs[i,0], vs[i,1], vs[i,2]) for i in range(vs.shape[0])]
    vertex = np.array(vs, dtype=[('x', 'f4'), ('y', 'f4'), ('z', 'f4')])
    
    face = np.empty(len(fs), dtype=[('vertex_indices', 'i4', (3,))])
    face['vertex_indices'] = fs
    
    el_vs = PlyElement.describe(vertex, 'vertex', comments=['vertices'])
    el_fs = PlyElement.describe(face, 'face', comments=['faces'])        

    PlyData([el_vs, el_fs]).write(path)
            
def customize_load_ply(path):
    plydata = PlyData.read(path)
    data_pd = pd.DataFrame(plydata.elements[0].data) 
    data_np = np.zeros((data_pd.shape[0], 3), dtype=np.float64)

    property_names = plydata.elements[0].data[0].dtype.names
    for i in range(3):  
        data_np[:, i] = data_pd[property_names[i]]

    ply_vertices = torch.from_numpy(data_np)
    ply_vertices = ply_vertices.float().to(device)
    return ply_vertices
    
def write_obj(verts, faces, file_name):
    with open(file_name, 'w') as fp:
        for i in range(verts.shape[0]):
            v = verts[i]
            fp.write('v %f %f %f\n' % (v[0], v[1], v[2]))

        for i in range(faces.shape[0]):
            f = faces[i]
            fp.write('f %d %d %d\n' % (f[0] + 1, f[1] + 1, f[2] + 1))

# %%
# setup smplx
s_model = smplx.create("./models", "smplx", gender = "male", num_pca_comps = 12, use_face_contour= False, ext = "pkl", dtype = torch.float64).to(device)
f_model = smplx.create("./models", "smplx", gender = "female", num_pca_comps = 12, use_face_contour= False, ext = "pkl", dtype = torch.float64).to(device)
body_model = f_model

pose_size = body_model.NUM_BODY_JOINTS * 3 # 54*3 
beta_size = body_model.NUM_BETAS # 10

betas = torch.zeros(beta_size, device=device, dtype=torch.double, requires_grad=True)
pose = torch.zeros(pose_size, device=device, dtype=torch.double, requires_grad=True)
trans = torch.zeros(3, device=device, dtype=torch.double, requires_grad=True)    
pos_dir = torch.zeros(3, device=device, dtype=torch.double, requires_grad=True)

# idx = 0
res = body_model(betas=betas.view(1, -1), body_pose=pose.view(1, -1), global_orient=pos_dir.view(1, -1), transl=trans.view(1,-1), return_verts=True, return_full_pose=True)
write_obj(res.vertices.view(-1,3), body_model.faces, "t.obj")

# %%
smplx_precompute_pattern = "/data/NFS/new_disk/chenxin/relightable-nr/data/white_walkshow/mesh_smplx/results/%03d-removebg-preview/000.pkl"
print(model_data)
print(model_data['body_pose'].shape)
print(model_data['left_hand_pose'].shape)

res = body_model(betas=model_data['betas'], 
           global_orient=model_data['global_orient'], 
           left_hand_pose=model_data['left_hand_pose'],
           right_hand_pose=model_data['right_hand_pose'],
           jaw_pose=model_data['jaw_pose'],
           leye_pose=model_data['leye_pose'],
           reye_pose=model_data['reye_pose'],
           expression=model_data['expression'],
           body_pose=model_data['body_pose_joint'])
write_obj(res.vertices.view(-1,3), body_model.faces, "t1.obj")
# Out:
# {'camera_rotation': tensor([[[1., 0., 0.],
#          [0., 1., 0.],
#          [0., 0., 1.]]], device='cuda:1', dtype=torch.float64), 'camera_translation': tensor([[-2.2852e-02,  6.9026e-02,  2.3333e+01]], device='cuda:1',
#        dtype=torch.float64), 'betas': tensor([[ 3.1941, -0.9010,  3.1141, -0.2805, -0.0660,  2.0125, -1.3411, -0.0242,
#           1.2103, -0.0469]], device='cuda:1', dtype=torch.float64), 'global_orient': tensor([[ 3.1834,  0.0446, -0.1491]], device='cuda:1', dtype=torch.float64), 'left_hand_pose': tensor([[-0.3915,  0.0575,  0.2200, -0.2511,  0.1584, -0.0458, -0.1827,  0.1439,
#          -0.1736, -0.0109,  0.0938,  0.0734]], device='cuda:1',
#        dtype=torch.float64), 'right_hand_pose': tensor([[-0.1808, -0.7088, -0.0313,  0.2641,  0.4155,  0.1189,  0.3650,  0.2739,
#           0.1288, -0.6526,  0.7052, -0.1389]], device='cuda:1',
#        dtype=torch.float64), 'jaw_pose': tensor([[0.0655, 0.0007, 0.0003]], device='cuda:1', dtype=torch.float64), 'leye_pose': tensor([[1.0582, 0.8691, 0.0725]], device='cuda:1', dtype=torch.float64), 'reye_pose': tensor([[ 0.6235, -1.2916,  0.4867]], device='cuda:1', dtype=torch.float64), 'expression': tensor([[ 0.2420, -0.2330, -0.5961, -0.0388,  0.1079, -0.3919,  0.3582, -0.1510,
#           0.2990,  0.2066]], device='cuda:1', dtype=torch.float64), 'body_pose_joint': tensor([[-0.1329, -0.0515, -0.0726, -0.3237,  0.0974,  0.1122,  0.3030,  0.0141,
#          -0.0088,  0.3244,  0.0277, -0.0811,  0.3811, -0.0591,  0.0418, -0.0512,
#          -0.0131,  0.0235,  0.1933,  0.1985, -0.0279,  0.3159, -0.0759,  0.1408,
#           0.0085,  0.0022,  0.0270,  0.0109,  0.0022,  0.0012,  0.0410,  0.0175,
#           0.0118, -0.1065,  0.0234, -0.0340,  0.1071, -0.0507, -0.3402,  0.0852,
#           0.1442,  0.3450, -0.1082,  0.0489,  0.0699,  0.1882, -0.0821, -0.9611,
#           0.2516,  0.1472,  0.9207,  0.3000, -0.5687,  0.1489,  0.3365,  0.6457,
#          -0.1938,  0.1095, -0.1818,  0.3758,  0.2095,  0.1443, -0.3369]],
#        device='cuda:1', dtype=torch.float64), 'body_pose': tensor([[ 0.2135, -0.3698,  0.1814,  0.7865,  0.5971, -0.0993,  0.3530, -1.1708,
#          -0.0364, -0.5817, -0.8560,  1.1105,  0.2895, -0.4953,  0.5413, -0.4968,
#           0.2598, -0.6867, -0.0977,  0.2807,  0.5811, -0.2314,  0.2744, -1.8403,
#           0.9414,  0.0917,  0.3675, -0.2340,  0.5022,  0.1581, -0.6394,  0.4691]],
#        device='cuda:1', dtype=torch.float64)}
# torch.Size([1, 32])
# torch.Size([1, 12])

# %%
load_precompute = True

frame_range = [111,156]

# body_ske_pattern = "/home/haines/datasets/models/%s/%d/openpose/skeleton_body/skeleton.txt"
# lhand_ske_pattern = "/home/haines/datasets/models/%s/%d/openpose/skeleton_hand_left/skeleton.txt"
# rhand_ske_pattern = "/home/haines/datasets/models/%s/%d/openpose/skeleton_hand_right/skeleton.txt"

smplx_precompute_pattern = "/data/NFS/new_disk/chenxin/relightable-nr/data/white_walkshow/mesh_smplx/results/%03d-removebg-preview/000.pkl"
target_mesh_pattern = "/data/NFS/new_disk/chenxin/relightable-nr/data/white_walkshow/mesh_pifu/result_%03d-removebg-preview_512.ply"
rs_mesh_pattern = '/data/NFS/new_disk/chenxin/relightable-nr/data/white_walkshow/mesh_smplx2pifu/rs_%03d.ply'
rs_params_pattern = '/data/NFS/new_disk/chenxin/relightable-nr/data/white_walkshow/mesh_smplx2pifu/ps_%03d.pkl'

torch.autograd.set_detect_anomaly(True)

chamfer_dist = ChamferDistance()

betas = []
pose = []
glob_t = []
glob_r = []
pose_size = body_model.NUM_BODY_JOINTS * 3 # 54*3 
hand_size = body_model.NUM_HAND_JOINTS * 3 # 15*3
beta_size = body_model.NUM_BETAS # 10

for iF in range(frame_range[0], frame_range[1]):
    
    # check target
    if not exists(target_mesh_pattern % iF):
        raise ValueError(target_mesh_pattern % iF)
        
    time_frame_start=time.time()
        
    # load ske
    #ske_body = load_ske(body_ske_pattern%iF)[OPOS_joints]
    #ske_lhand = load_ske(lhand_ske_pattern%iF)[OPOS_joints]
    #ske_rhand = load_ske(rhand_ske_pattern%iF)[OPOS_joints]
    
    # load target
    target_vertices = customize_load_ply(target_mesh_pattern%iF)
    
    # init params
    if iF == frame_range[0]:
        # load smplx
        epoch = 1001
        # left_hand_pose = torch.zeros(hand_size, device=device, dtype=torch.double, requires_grad=True)
        # right_hand_pose = torch.zeros(hand_size, device=device, dtype=torch.double, requires_grad=True)
        if load_precompute:
            smplx_params = customize_load_smplx_params('/data/NFS/new_disk/chenxin/relightable-nr/data/white_walkshow/mesh_smplx2pifu/ps_%03d.pkl'%iF)
            betas = smplx_params['betas'].clone().detach().requires_grad_(True).double()
            pose = smplx_params['body_pose_joint'].clone().detach().requires_grad_(True).double()
            glob_t = smplx_params['transl'].clone().detach().requires_grad_(True).double()
            glob_r = smplx_params['global_orient'].clone().detach().requires_grad_(True).double()
            print("Load first frame ...")
            continue
        else:
            smplx_params = customize_load_smplx_params(smplx_precompute_pattern%iF)
            betas = smplx_params['betas'].clone().detach().requires_grad_(True).double()
            pose = smplx_params['body_pose_joint'].clone().detach().requires_grad_(True).double()
            glob_t = torch.zeros(3, device=device, dtype=torch.double, requires_grad=True)
            glob_r = torch.zeros(3, device=device, dtype=torch.double, requires_grad=True)   
            
    else:
        smplx_params = customize_load_smplx_params(smplx_precompute_pattern%iF)
        epoch = 501
    
    ##########################################
    # optmize with global with target
    ##########################################
    # optmizer
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(params=[betas, pose, glob_t, glob_r], lr = 0.01)
    # optimizer = torch.optim.Adam(params=[glob_t, glob_r], lr = 0.01)
    for i in range(epoch):
        optimizer.zero_grad()

        # update smplx
        time_start=time.time()
        res = body_model(betas=betas, 
               global_orient=glob_r.view(1,-1), # smplx_params['global_orient'], 
               transl=glob_t.view(1,-1), 
               left_hand_pose=smplx_params['left_hand_pose'],
               right_hand_pose=smplx_params['right_hand_pose'],
               jaw_pose=smplx_params['jaw_pose'],
               leye_pose=smplx_params['leye_pose'],
               reye_pose=smplx_params['reye_pose'],
               expression=smplx_params['expression'],
               body_pose=pose,
               return_verts=True,
               return_full_pose=True)
        time_smpl=time.time() - time_start
        
        d1, d2 = chamfer_dist(res.vertices.float(), target_vertices.view(1,-1,3).float())
        loss = (torch.mean(d1)) + (torch.mean(d2))
        ##########################################
        # TO-DO
        # add loss - porjected joints 
        # add pose embedding - 3D pose embedding prior (see vposer in smplify-x)
        ##########################################
        time_chamdist=time.time()-time_start-time_smpl

        loss.backward()
        optimizer.step()
        time_backward=time.time()-time_start-time_smpl-time_chamdist

        if i % 40 == 0:
            print("epch: %d,  loss: %f, t_smpl: %f, t_chamDist: %f, t_backward: %f" % (i, loss.item(), time_smpl, time_chamdist, time_backward))
        if loss.item() < 0.000300:
            print("    stop optmization")
            break
    res = body_model(betas=betas, 
           global_orient=glob_r.view(1,-1), # smplx_params['global_orient'], 
           transl=glob_t.view(1,-1), 
           left_hand_pose=smplx_params['left_hand_pose'],
           right_hand_pose=smplx_params['right_hand_pose'],
           jaw_pose=smplx_params['jaw_pose'],
           leye_pose=smplx_params['leye_pose'],
           reye_pose=smplx_params['reye_pose'],
           expression=smplx_params['expression'],
           body_pose=pose,
           return_verts=True,
           return_full_pose=True)
    rs_data = smplx_params
    rs_data['betas'] = betas.clone()
    rs_data['body_pose_joint'] = pose.clone()
    rs_data['transl'] = glob_t.view(1,-1).clone()
    rs_data['global_orient'] = glob_r.view(1,-1).clone()
    customize_save_smplx_params(rs_data, rs_params_pattern%iF)
    time_opt = time.time()
    
    customize_save_ply(res.vertices.view(-1,3).clone().detach().cpu(), body_model.faces, rs_mesh_pattern%iF)
    
    # write_obj(res.vertices.view(-1,3), body_model.faces, rs_mesh_pattern%iF)
    time_total = time.time() - time_frame_start
    time_save = time.time() - time_opt
# epch: 160,  loss: 0.000482, t_smpl: 0.307878, t_chamDist: 0.012340, t_backward: 0.073265
# epch: 200,  loss: 0.000478, t_smpl: 0.279212, t_chamDist: 0.006567, t_backward: 0.080409
# epch: 240,  loss: 0.000475, t_smpl: 0.305106, t_chamDist: 0.029027, t_backward: 0.084548
# epch: 280,  loss: 0.000471, t_smpl: 0.278646, t_chamDist: 0.005488, t_backward: 0.073507
# epch: 320,  loss: 0.000467, t_smpl: 0.301087, t_chamDist: 0.005326, t_backward: 0.107193
# epch: 360,  loss: 0.000458, t_smpl: 0.313461, t_chamDist: 0.005313, t_backward: 0.073754
# epch: 400,  loss: 0.000446, t_smpl: 0.230778, t_chamDist: 0.004609, t_backward: 0.089625
# epch: 440,  loss: 0.000441, t_smpl: 0.320521, t_chamDist: 0.012610, t_backward: 0.071272
# epch: 480,  loss: 0.000439, t_smpl: 0.300640, t_chamDist: 0.042225, t_backward: 0.084201
# Frame 120 Save /data/NFS/new_disk/chenxin/relightable-nr/data/white_walkshow/mesh_smplx2pifu/rs_120.ply, t_save 0.489734, t_totall 192.987872
# epch: 0,  loss: 0.000610, t_smpl: 0.282165, t_chamDist: 0.017347, t_backward: 0.085024
# epch: 40,  loss: 0.000490, t_smpl: 0.224933, t_chamDist: 0.032936, t_backward: 0.075803
# epch: 80,  loss: 0.000478, t_smpl: 0.225406, t_chamDist: 0.010344, t_backward: 0.081536
# epch: 120,  loss: 0.000474, t_smpl: 0.282972, t_chamDist: 0.015079, t_backward: 0.086710
# epch: 160,  loss: 0.000471, t_smpl: 0.229805, t_chamDist: 0.015994, t_backward: 0.077254
# epch: 200,  loss: 0.000469, t_smpl: 0.223423, t_chamDist: 0.005429, t_backward: 0.080062
# epch: 240,  loss: 0.000468, t_smpl: 0.285344, t_chamDist: 0.005466, t_backward: 0.090096
# epch: 280,  loss: 0.000467, t_smpl: 0.277542, t_chamDist: 0.028294, t_backward: 0.083892
# epch: 320,  loss: 0.000467, t_smpl: 0.280409, t_chamDist: 0.011674, t_backward: 0.069046
# epch: 360,  loss: 0.000466, t_smpl: 0.290597, t_chamDist: 0.018615, t_backward: 0.069480
# epch: 400,  loss: 0.000465, t_smpl: 0.274630, t_chamDist: 0.017495, t_backward: 0.092583
# epch: 440,  loss: 0.000465, t_smpl: 0.292789, t_chamDist: 0.011445, t_backward: 0.075641
# epch: 480,  loss: 0.000465, t_smpl: 0.292911, t_chamDist: 0.045128, t_backward: 0.078846
# Frame 121 Save /data/NFS/new_disk/chenxin/relightable-nr/data/white_walkshow/mesh_smplx2pifu/rs_121.ply, t_save 0.418191, t_totall 196.462689
# epch: 0,  loss: 0.000964, t_smpl: 0.224365, t_chamDist: 0.024292, t_backward: 0.084354
# epch: 40,  loss: 0.000615, t_smpl: 0.281619, t_chamDist: 0.023408, t_backward: 0.062793
# epch: 80,  loss: 0.000586, t_smpl: 0.307614, t_chamDist: 0.018023, t_backward: 0.088985
# epch: 120,  loss: 0.000568, t_smpl: 0.282039, t_chamDist: 0.007352, t_backward: 0.077933
# epch: 160,  loss: 0.000560, t_smpl: 0.277925, t_chamDist: 0.005833, t_backward: 0.089175
# epch: 200,  loss: 0.000556, t_smpl: 0.279885, t_chamDist: 0.005320, t_backward: 0.070110
# epch: 280,  loss: 0.000425, t_smpl: 0.276433, t_chamDist: 0.011043, t_backward: 0.082420
# epch: 320,  loss: 0.000424, t_smpl: 0.283587, t_chamDist: 0.019802, t_backward: 0.073753
# epch: 360,  loss: 0.000424, t_smpl: 0.269413, t_chamDist: 0.038589, t_backward: 0.062845
# epch: 400,  loss: 0.000423, t_smpl: 0.318434, t_chamDist: 0.026245, t_backward: 0.066068
# epch: 440,  loss: 0.000423, t_smpl: 0.221371, t_chamDist: 0.004676, t_backward: 0.084502
# epch: 480,  loss: 0.000422, t_smpl: 0.287597, t_chamDist: 0.042201, t_backward: 0.080194
# Frame 124 Save /data/NFS/new_disk/chenxin/relightable-nr/data/white_walkshow/mesh_smplx2pifu/rs_124.ply, t_save 0.439651, t_totall 194.157443
# epch: 0,  loss: 0.000620, t_smpl: 0.281134, t_chamDist: 0.019445, t_backward: 0.092824
# epch: 40,  loss: 0.000473, t_smpl: 0.283260, t_chamDist: 0.025643, t_backward: 0.065853
# epch: 80,  loss: 0.000467, t_smpl: 0.297502, t_chamDist: 0.022616, t_backward: 0.081874
# epch: 120,  loss: 0.000466, t_smpl: 0.310845, t_chamDist: 0.005359, t_backward: 0.074755
# epch: 160,  loss: 0.000465, t_smpl: 0.306328, t_chamDist: 0.014466, t_backward: 0.089803
# epch: 200,  loss: 0.000464, t_smpl: 0.318905, t_chamDist: 0.004923, t_backward: 0.080979
# epch: 240,  loss: 0.000464, t_smpl: 0.227323, t_chamDist: 0.025877, t_backward: 0.075697
# epch: 280,  loss: 0.000463, t_smpl: 0.303176, t_chamDist: 0.026665, t_backward: 0.091428
# epch: 320,  loss: 0.000463, t_smpl: 0.286496, t_chamDist: 0.021586, t_backward: 0.096462
# epch: 360,  loss: 0.000462, t_smpl: 0.278863, t_chamDist: 0.005359, t_backward: 0.076163
# epch: 400,  loss: 0.000462, t_smpl: 0.265288, t_chamDist: 0.021799, t_backward: 0.094708
# epch: 440,  loss: 0.000462, t_smpl: 0.286453, t_chamDist: 0.032192, t_backward: 0.102727
# epch: 480,  loss: 0.000461, t_smpl: 0.279131, t_chamDist: 0.008088, t_backward: 0.090453
# Frame 125 Save /data/NFS/new_disk/chenxin/relightable-nr/data/white_walkshow/mesh_smplx2pifu/rs_125.ply, t_save 0.541597, t_totall 203.080847
# epch: 0,  loss: 0.001281, t_smpl: 0.229096, t_chamDist: 0.018695, t_backward: 0.072229
# epch: 40,  loss: 0.000515, t_smpl: 0.281161, t_chamDist: 0.011166, t_backward: 0.075037
# epch: 80,  loss: 0.000481, t_smpl: 0.275138, t_chamDist: 0.009860, t_backward: 0.080603
# epch: 120,  loss: 0.000470, t_smpl: 0.291570, t_chamDist: 0.021726, t_backward: 0.077840
# epch: 160,  loss: 0.000463, t_smpl: 0.289353, t_chamDist: 0.028229, t_backward: 0.081486
# epch: 200,  loss: 0.000456, t_smpl: 0.294800, t_chamDist: 0.005304, t_backward: 0.082939
# epch: 240,  loss: 0.000449, t_smpl: 0.286198, t_chamDist: 0.015898, t_backward: 0.073232
# epch: 280,  loss: 0.000439, t_smpl: 0.283639, t_chamDist: 0.020024, t_backward: 0.074200
# epch: 320,  loss: 0.000435, t_smpl: 0.297791, t_chamDist: 0.006995, t_backward: 0.074534
# epch: 360,  loss: 0.000431, t_smpl: 0.251565, t_chamDist: 0.005798, t_backward: 0.071850
# epch: 400,  loss: 0.000429, t_smpl: 0.286521, t_chamDist: 0.011254, t_backward: 0.070172
# epch: 440,  loss: 0.000426, t_smpl: 0.283947, t_chamDist: 0.007281, t_backward: 0.090426
# epch: 480,  loss: 0.000424, t_smpl: 0.282828, t_chamDist: 0.017059, t_backward: 0.079885
# Frame 126 Save /data/NFS/new_disk/chenxin/relightable-nr/data/white_walkshow/mesh_smplx2pifu/rs_126.ply, t_save 0.433863, t_totall 194.252522
# epch: 0,  loss: 0.000748, t_smpl: 0.275792, t_chamDist: 0.008690, t_backward: 0.074497
# epch: 40,  loss: 0.000500, t_smpl: 0.281413, t_chamDist: 0.010924, t_backward: 0.090620
# epch: 80,  loss: 0.000468, t_smpl: 0.307929, t_chamDist: 0.038326, t_backward: 0.065548
# epch: 120,  loss: 0.000448, t_smpl: 0.277273, t_chamDist: 0.005443, t_backward: 0.068936
# epch: 160,  loss: 0.000432, t_smpl: 0.285561, t_chamDist: 0.022044, t_backward: 0.084608
# epch: 200,  loss: 0.000422, t_smpl: 0.280544, t_chamDist: 0.005173, t_backward: 0.064626
# epch: 240,  loss: 0.000417, t_smpl: 0.280142, t_chamDist: 0.007791, t_backward: 0.068120
# epch: 280,  loss: 0.000413, t_smpl: 0.290483, t_chamDist: 0.006338, t_backward: 0.073525
# epch: 320,  loss: 0.000410, t_smpl: 0.299586, t_chamDist: 0.005346, t_backward: 0.081811
# epch: 360,  loss: 0.000408, t_smpl: 0.301917, t_chamDist: 0.006656, t_backward: 0.094072
# epch: 400,  loss: 0.000407, t_smpl: 0.279018, t_chamDist: 0.008802, t_backward: 0.077023
# epch: 440,  loss: 0.000406, t_smpl: 0.276267, t_chamDist: 0.014808, t_backward: 0.086286
# epch: 480,  loss: 0.000406, t_smpl: 0.318228, t_chamDist: 0.005553, t_backward: 0.082053
# Frame 127 Save /data/NFS/new_disk/chenxin/relightable-nr/data/white_walkshow/mesh_smplx2pifu/rs_127.ply, t_save 0.400436, t_totall 189.716913
# epch: 0,  loss: 0.000493, t_smpl: 0.233404, t_chamDist: 0.015393, t_backward: 0.068036
# epch: 40,  loss: 0.000415, t_smpl: 0.223061, t_chamDist: 0.004584, t_backward: 0.073339
# epch: 80,  loss: 0.000408, t_smpl: 0.294516, t_chamDist: 0.006573, t_backward: 0.074635
# epch: 120,  loss: 0.000406, t_smpl: 0.311519, t_chamDist: 0.020448, t_backward: 0.076157
# epch: 160,  loss: 0.000405, t_smpl: 0.220059, t_chamDist: 0.006297, t_backward: 0.073717
# epch: 200,  loss: 0.000404, t_smpl: 0.288784, t_chamDist: 0.014268, t_backward: 0.064954
# epch: 240,  loss: 0.000404, t_smpl: 0.282540, t_chamDist: 0.012051, t_backward: 0.082551
# epch: 280,  loss: 0.000403, t_smpl: 0.287484, t_chamDist: 0.030027, t_backward: 0.073669
# epch: 320,  loss: 0.000403, t_smpl: 0.274988, t_chamDist: 0.004987, t_backward: 0.084098
# epch: 360,  loss: 0.000403, t_smpl: 0.302445, t_chamDist: 0.005269, t_backward: 0.067643
# epch: 400,  loss: 0.000403, t_smpl: 0.278919, t_chamDist: 0.005300, t_backward: 0.098499
# epch: 440,  loss: 0.000402, t_smpl: 0.273437, t_chamDist: 0.007586, t_backward: 0.080503
# epch: 480,  loss: 0.000402, t_smpl: 0.237433, t_chamDist: 0.010244, t_backward: 0.087785
# Frame 128 Save /data/NFS/new_disk/chenxin/relightable-nr/data/white_walkshow/mesh_smplx2pifu/rs_128.ply, t_save 0.477247, t_totall 192.374316
# epch: 0,  loss: 0.000541, t_smpl: 0.277320, t_chamDist: 0.034592, t_backward: 0.082086
# epch: 40,  loss: 0.000403, t_smpl: 0.274643, t_chamDist: 0.005313, t_backward: 0.077183
# epch: 80,  loss: 0.000398, t_smpl: 0.300301, t_chamDist: 0.017075, t_backward: 0.088022
# epch: 120,  loss: 0.000396, t_smpl: 0.285300, t_chamDist: 0.030874, t_backward: 0.082124
# epch: 160,  loss: 0.000395, t_smpl: 0.302156, t_chamDist: 0.020689, t_backward: 0.081819
# epch: 200,  loss: 0.000394, t_smpl: 0.302903, t_chamDist: 0.005410, t_backward: 0.070291
# epch: 240,  loss: 0.000394, t_smpl: 0.280467, t_chamDist: 0.005318, t_backward: 0.069769
# epch: 280,  loss: 0.000393, t_smpl: 0.299759, t_chamDist: 0.023590, t_backward: 0.080780
# epch: 320,  loss: 0.000392, t_smpl: 0.281142, t_chamDist: 0.005250, t_backward: 0.074558
# epch: 360,  loss: 0.000391, t_smpl: 0.281713, t_chamDist: 0.010004, t_backward: 0.074326
# epch: 400,  loss: 0.000390, t_smpl: 0.283058, t_chamDist: 0.005572, t_backward: 0.066447
# epch: 440,  loss: 0.000390, t_smpl: 0.281607, t_chamDist: 0.005392, t_backward: 0.074249
# epch: 480,  loss: 0.000390, t_smpl: 0.291968, t_chamDist: 0.005389, t_backward: 0.079738
# Frame 129 Save /data/NFS/new_disk/chenxin/relightable-nr/data/white_walkshow/mesh_smplx2pifu/rs_129.ply, t_save 0.454440, t_totall 191.815047
# epch: 0,  loss: 0.000478, t_smpl: 0.304842, t_chamDist: 0.028753, t_backward: 0.085464
# epch: 40,  loss: 0.000401, t_smpl: 0.331899, t_chamDist: 0.013406, t_backward: 0.072113
# epch: 80,  loss: 0.000397, t_smpl: 0.277981, t_chamDist: 0.032406, t_backward: 0.085698
# epch: 120,  loss: 0.000396, t_smpl: 0.292197, t_chamDist: 0.019176, t_backward: 0.076252
# epch: 160,  loss: 0.000395, t_smpl: 0.256968, t_chamDist: 0.004635, t_backward: 0.104885
# epch: 200,  loss: 0.000395, t_smpl: 0.262146, t_chamDist: 0.008627, t_backward: 0.082823
# epch: 240,  loss: 0.000394, t_smpl: 0.220595, t_chamDist: 0.010759, t_backward: 0.072523
# epch: 280,  loss: 0.000394, t_smpl: 0.294084, t_chamDist: 0.008708, t_backward: 0.097040
# epch: 320,  loss: 0.000393, t_smpl: 0.277012, t_chamDist: 0.008863, t_backward: 0.075382
# epch: 360,  loss: 0.000393, t_smpl: 0.233157, t_chamDist: 0.012093, t_backward: 0.081900
# epch: 400,  loss: 0.000393, t_smpl: 0.228463, t_chamDist: 0.007537, t_backward: 0.075045
# epch: 440,  loss: 0.000392, t_smpl: 0.279624, t_chamDist: 0.007000, t_backward: 0.084959
# epch: 480,  loss: 0.000392, t_smpl: 0.283067, t_chamDist: 0.005396, t_backward: 0.072313
# Frame 130 Save /data/NFS/new_disk/chenxin/relightable-nr/data/white_walkshow/mesh_smplx2pifu/rs_130.ply, t_save 0.435503, t_totall 191.260825
# epch: 0,  loss: 0.000626, t_smpl: 0.281290, t_chamDist: 0.040812, t_backward: 0.074990
# epch: 40,  loss: 0.000488, t_smpl: 0.275520, t_chamDist: 0.015254, t_backward: 0.086531
# epch: 80,  loss: 0.000480, t_smpl: 0.279336, t_chamDist: 0.005834, t_backward: 0.067391
# epch: 120,  loss: 0.000477, t_smpl: 0.284169, t_chamDist: 0.017973, t_backward: 0.082841
# epch: 160,  loss: 0.000475, t_smpl: 0.298374, t_chamDist: 0.025548, t_backward: 0.068974
# epch: 200,  loss: 0.000473, t_smpl: 0.290266, t_chamDist: 0.005419, t_backward: 0.086608
# epch: 240,  loss: 0.000472, t_smpl: 0.228191, t_chamDist: 0.015351, t_backward: 0.101761
# epch: 280,  loss: 0.000471, t_smpl: 0.277845, t_chamDist: 0.005432, t_backward: 0.076153
# epch: 320,  loss: 0.000470, t_smpl: 0.306150, t_chamDist: 0.005387, t_backward: 0.081165
# epch: 360,  loss: 0.000470, t_smpl: 0.276087, t_chamDist: 0.005404, t_backward: 0.090863
# epch: 400,  loss: 0.000469, t_smpl: 0.270816, t_chamDist: 0.036068, t_backward: 0.074075
# epch: 440,  loss: 0.000469, t_smpl: 0.293331, t_chamDist: 0.029065, t_backward: 0.071380
# epch: 480,  loss: 0.000468, t_smpl: 0.281501, t_chamDist: 0.005881, t_backward: 0.077028
# Frame 131 Save /data/NFS/new_disk/chenxin/relightable-nr/data/white_walkshow/mesh_smplx2pifu/rs_131.ply, t_save 0.453946, t_totall 192.540265
# epch: 0,  loss: 0.000636, t_smpl: 0.314653, t_chamDist: 0.005898, t_backward: 0.072029
# epch: 40,  loss: 0.000463, t_smpl: 0.289532, t_chamDist: 0.005467, t_backward: 0.077065
# epch: 80,  loss: 0.000445, t_smpl: 0.285141, t_chamDist: 0.032040, t_backward: 0.078256
# epch: 120,  loss: 0.000438, t_smpl: 0.301252, t_chamDist: 0.014271, t_backward: 0.108610
# epch: 160,  loss: 0.000433, t_smpl: 0.294762, t_chamDist: 0.005247, t_backward: 0.072729
# epch: 200,  loss: 0.000429, t_smpl: 0.295993, t_chamDist: 0.007691, t_backward: 0.067638
# epch: 240,  loss: 0.000426, t_smpl: 0.306731, t_chamDist: 0.016184, t_backward: 0.077182
# epch: 280,  loss: 0.000423, t_smpl: 0.308286, t_chamDist: 0.009232, t_backward: 0.076295
# epch: 320,  loss: 0.000421, t_smpl: 0.281489, t_chamDist: 0.026695, t_backward: 0.074476
# epch: 360,  loss: 0.000419, t_smpl: 0.223091, t_chamDist: 0.004634, t_backward: 0.085335
# epch: 400,  loss: 0.000417, t_smpl: 0.293779, t_chamDist: 0.017636, t_backward: 0.090783
# epch: 440,  loss: 0.000415, t_smpl: 0.227407, t_chamDist: 0.012072, t_backward: 0.066954
# epch: 480,  loss: 0.000413, t_smpl: 0.279387, t_chamDist: 0.005241, t_backward: 0.070526
# Frame 132 Save /data/NFS/new_disk/chenxin/relightable-nr/data/white_walkshow/mesh_smplx2pifu/rs_132.ply, t_save 0.472611, t_totall 191.952618
# epch: 0,  loss: 0.000466, t_smpl: 0.282982, t_chamDist: 0.009934, t_backward: 0.086458
# epch: 40,  loss: 0.000406, t_smpl: 0.282310, t_chamDist: 0.015728, t_backward: 0.081132
# epch: 80,  loss: 0.000402, t_smpl: 0.285445, t_chamDist: 0.004586, t_backward: 0.069740
# epch: 120,  loss: 0.000400, t_smpl: 0.278420, t_chamDist: 0.011009, t_backward: 0.083022
# epch: 160,  loss: 0.000398, t_smpl: 0.221742, t_chamDist: 0.027089, t_backward: 0.076017
# epch: 200,  loss: 0.000396, t_smpl: 0.299317, t_chamDist: 0.016281, t_backward: 0.085320
# epch: 240,  loss: 0.000395, t_smpl: 0.286912, t_chamDist: 0.007089, t_backward: 0.080935
# epch: 280,  loss: 0.000394, t_smpl: 0.281897, t_chamDist: 0.017349, t_backward: 0.074975
# epch: 320,  loss: 0.000393, t_smpl: 0.278398, t_chamDist: 0.015770, t_backward: 0.101752
# epch: 360,  loss: 0.000392, t_smpl: 0.296333, t_chamDist: 0.011631, t_backward: 0.085643
# epch: 400,  loss: 0.000392, t_smpl: 0.285324, t_chamDist: 0.030511, t_backward: 0.094281
# epch: 440,  loss: 0.000391, t_smpl: 0.263547, t_chamDist: 0.006363, t_backward: 0.090390
# epch: 480,  loss: 0.000391, t_smpl: 0.281388, t_chamDist: 0.008224, t_backward: 0.079281
# Frame 133 Save /data/NFS/new_disk/chenxin/relightable-nr/data/white_walkshow/mesh_smplx2pifu/rs_133.ply, t_save 0.443675, t_totall 190.763235
# epch: 0,  loss: 0.000504, t_smpl: 0.242588, t_chamDist: 0.012230, t_backward: 0.074410
# epch: 40,  loss: 0.000390, t_smpl: 0.216955, t_chamDist: 0.005154, t_backward: 0.066177
# epch: 80,  loss: 0.000383, t_smpl: 0.283407, t_chamDist: 0.005335, t_backward: 0.073129
# epch: 120,  loss: 0.000381, t_smpl: 0.278732, t_chamDist: 0.005383, t_backward: 0.071683
# epch: 160,  loss: 0.000379, t_smpl: 0.263112, t_chamDist: 0.011533, t_backward: 0.075034
# epch: 200,  loss: 0.000378, t_smpl: 0.402215, t_chamDist: 0.005875, t_backward: 0.087140
# epch: 240,  loss: 0.000377, t_smpl: 0.230344, t_chamDist: 0.016570, t_backward: 0.076429
# epch: 280,  loss: 0.000376, t_smpl: 0.282533, t_chamDist: 0.006568, t_backward: 0.066309
# epch: 320,  loss: 0.000376, t_smpl: 0.281911, t_chamDist: 0.006373, t_backward: 0.070275
# epch: 360,  loss: 0.000375, t_smpl: 0.275219, t_chamDist: 0.020556, t_backward: 0.072645
# epch: 400,  loss: 0.000377, t_smpl: 0.327583, t_chamDist: 0.020700, t_backward: 0.067739
# epch: 440,  loss: 0.000375, t_smpl: 0.279526, t_chamDist: 0.005392, t_backward: 0.084043
# epch: 480,  loss: 0.000375, t_smpl: 0.285641, t_chamDist: 0.023465, t_backward: 0.075160
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-129-90e3ec9dde42> in <module>
#      88                body_pose=pose,
#      89                return_verts=True,
# ---> 90                return_full_pose=True)
#      91         time_smpl=time.time() - time_start
#      92
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/smplx/body_models.py in forward(self, betas, global_orient, body_pose, left_hand_pose, right_hand_pose, transl, expression, jaw_pose, leye_pose, reye_pose, return_verts, return_full_pose, pose2rot, **kwargs)
#     922                                self.J_regressor, self.parents,
#     923                                self.lbs_weights, pose2rot=pose2rot,
# --> 924                                dtype=self.dtype)
#     925
#     926         lmk_faces_idx = self.lmk_faces_idx.unsqueeze(
#
# /usr/local/lib/python3.6/dist-packages/smplx/lbs.py in lbs(betas, pose, v_template, shapedirs, posedirs, J_regressor, parents, lbs_weights, pose2rot, dtype)
#     204     v_posed = pose_offsets + v_shaped
#     205     # 4. Get the global joint location
# --> 206     J_transformed, A = batch_rigid_transform(rot_mats, J, parents, dtype=dtype)
#     207
#     208     # 5. Do skinning:
#
# /usr/local/lib/python3.6/dist-packages/smplx/lbs.py in batch_rigid_transform(rot_mats, joints, parents, dtype)
#     353         # No need for rotation, since it's identity when at rest
#     354         curr_res = torch.matmul(transform_chain[parents[i]],
# --> 355                                 transforms_mat[:, i])
#     356         transform_chain.append(curr_res)
#     357
#
# /usr/lib/python3.6/traceback.py in format_stack(f, limit)
#     195     if f is None:
#     196         f = sys._getframe().f_back
# --> 197     return format_list(extract_stack(f, limit=limit))
#     198
#     199
#
# /usr/lib/python3.6/traceback.py in format_list(extracted_list)
#      37     whose source text line is not None.
#      38     """
# ---> 39     return StackSummary.from_list(extracted_list).format()
#      40
#      41 #
#
# /usr/lib/python3.6/traceback.py in format(self)
#     422                 frame.filename, frame.lineno, frame.name))
#     423             if frame.line:
# --> 424                 row.append('    {}\n'.format(frame.line.strip()))
#     425             if frame.locals:
#     426                 for name, value in sorted(frame.locals.items()):
#
# KeyboardInterrupt:

# %%
# Out:
# array([[    3,     1,     0],
#        [    7,     5,     4],
#        [   12,    14,    13],
#        ...,
#        [ 9944, 10097, 10084],
#        [ 9940, 10084, 10071],
#        [10071, 10058,  9932]], dtype=uint32)

# %%
rs_mesh_pattern = '/data/NFS/new_disk/chenxin/relightable-nr/data/white_walkshow/mesh_smplx2pifu/rs_%03d.obj'
res = body_model(betas=model_data['betas'], 
       global_orient=glob_r.view(1,-1), # model_data['global_orient'], 
       transl=glob_t.view(1,-1), 
       left_hand_pose=model_data['left_hand_pose'],
       right_hand_pose=model_data['right_hand_pose'],
       jaw_pose=model_data['jaw_pose'],
       leye_pose=model_data['leye_pose'],
       reye_pose=model_data['reye_pose'],
       expression=model_data['expression'],
       body_pose=model_data['body_pose_joint'],
       return_verts=True,
       return_full_pose=True)
write_obj(res.vertices.view(-1,3), body_model.faces, rs_mesh_pattern%iF)

# %%
# back 
    # optimize joint with joint
#     for i in range(1500):
#         optimizer.zero_grad()

#         res = body_model(betas=betas.view(1, -1), 
#                       body_pose=pose.view(1, -1), 
#                       global_orient=pos_dir.view(1, -1), 
#                       # left_hand_pose=left_hand_pose.view(1,-1),
#                       # right_hand_pose=right_hand_pose.view(1, -1),
#                       transl=trans.view(1,-1), 
#                       return_verts=True, 
#                       return_full_pose=True)

#         j = res.joints.squeeze()

#         s = skeleton[OPOS_joints]

#         # body
#         s = torch.cat([s, (skeleton[1] / 2 + skeleton[8] / 2).unsqueeze(0)],0)
#         s = torch.cat([s, (skeleton[1] / 4 + 3 * skeleton[8] / 4).unsqueeze(0)],0)
#         s = torch.cat([s, (skeleton[1] / 8 + 7 * skeleton[8] / 8).unsqueeze(0)],0)
#         s = torch.cat([s, (5 * skeleton[1] / 8 + 3 * skeleton[8] / 8).unsqueeze(0)],0)

#         loss = criterion(j[SMPL_joints], s.to(device))

#         loss.backward()
#         optimizer.step()

#         if i % 100 == 0:
#             print("epch: %d,  loss: %f" % (i, loss.item()))
#     # save output

#     # write_obj(res.vertices.view(-1,3), s_model.faces, "t1.obj")
        
    # optimize shape and pose with joint

# %%
# backup
    d1, d2 = chamfer_dist(res.vertices.float(), ply_vertices.view(1,-1,3).float())
    nloss = (torch.mean(d1)) + (torch.mean(d2))
    if nloss > 0.001:
        optimizer = torch.optim.Adam(params=[betas, pose, pos_dir, trans], lr = 0.01)
        for i in range(1500):
            optimizer.zero_grad()

            res = s_model(betas=betas.view(1, -1), 
                          body_pose=pose.view(1, -1), 
                          global_orient=pos_dir.view(1, -1), 
                          transl=trans.view(1,-1), 
                          return_verts=True, 
                          return_full_pose=True)

            j = res.joints.cpu().squeeze()
            s = skeleton[OPOS_joints]

            # body
            s = torch.cat([s, (skeleton[1] / 2 + skeleton[8] / 2).unsqueeze(0)],0)
            s = torch.cat([s, (skeleton[1] / 4 + 3 * skeleton[8] / 4).unsqueeze(0)],0)
            s = torch.cat([s, (skeleton[1] / 8 + 7 * skeleton[8] / 8).unsqueeze(0)],0)
            s = torch.cat([s, (5 * skeleton[1] / 8 + 3 * skeleton[8] / 8).unsqueeze(0)],0)

            loss = criterion(j[SMPL_joints], s)

            loss.backward()
            optimizer.step()

            if i % 100 == 0:
                print("epch: %d,  loss: %f" % (i, loss.item()))
        # write_obj(res.vertices.view(-1,3), s_model.faces, "t2.obj")
        
    # optimize joint with target
    if nloss > 0.001:
        optimizer = torch.optim.Adam(params=[betas, pose, pos_dir, trans], lr = 0.01)
        epoch = 1500
    else:
        epoch = 500
        optimizer = torch.optim.Adam(params=[pose, pos_dir, trans], lr = 0.01)   
    for i in range(epoch):
        optimizer.zero_grad()

        res = s_model(betas=betas.view(1, -1), body_pose=pose.view(1, -1), global_orient=pos_dir.view(1, -1), transl=trans.view(1,-1), return_verts=True, return_full_pose=True)
        d1, d2 = chamfer_dist(res.vertices.float(), ply_vertices.view(1,-1,3).float())
        loss = (torch.mean(d1)) + (torch.mean(d2))

        loss.backward()
        optimizer.step()

        if i % 100 == 0:
            print("epch: %d,  loss: %f" % (i, loss.item()))

    res = s_model(betas=betas.view(1, -1), body_pose=pose.view(1, -1), global_orient=pos_dir.view(1, -1), transl=trans.view(1,-1), return_verts=True, return_full_pose=True)
    write_obj(res.vertices.view(-1,3), s_model.faces, "./%s_smpl/%06d.obj"% (seq, idx))
